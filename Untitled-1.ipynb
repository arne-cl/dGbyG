# %%
import rdkit
from rdkit import Chem

# %%
import rdkit.Chem


rdkit.Chem.MolFromSmiles('[H]OC1=NC2=C(N=[C](O[H])=N2)C(O[H])=N1')
# Out:
# [09:52:32] Explicit valence for atom # 6 C, 5, is greater than permitted

# %%
mol = Chem.MolFromSmiles('[H]OC1=NC2=C(N=[C](O[H])=N2)C(O[H])=N1', sanitize=False)

# %%
mol

# %%
Chem.MolFromInchi('InChI=1S/C5H3N4O3/c10-3-1-2(7-4(11)6-1)8-5(12)9-3/h(H3,6,7,8,9,10,11,12)', sanitize=False)
